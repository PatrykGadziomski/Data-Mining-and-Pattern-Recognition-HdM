# %% [markdown]
# # Data Mining Versuch Document Classification
# * **Autor**: Prof. Dr. Johannes Maucher
# * **Datum**: 06.11.2015
# * **Studierende**: Paul Michels (pm080), Erzan Gashi (eg053), Patryk Gadziomski (pg058)
#
# [Übersicht Versuche im Data Mining Praktikum](http://maucher.pages.mi.hdm-stuttgart.de/ai/page/dm/)
#
# ## Abgabe:
#
# - **Abzugeben ist das Jupyter Notebook mit dem verlangten Implementierungen und den entsprechenden Ausgaben.**
# - **Das Notebook ist als .ipynb und als .html abzugeben.**
# - **Klausurelevante Fragen sind Dokument "Fragenkatalog Datamining" zu finden.**
# - Antworten auf Fragen im Notebook, Diskussionen und Beschreibung der Ergebnisse sind optional (aber empfohlen) und werden nicht bewertet.
#
# * [Übersicht Data Mining Praktikum](https://maucher.pages.mi.hdm-stuttgart.de/ai/page/dm/)
#
#
# # Einführung
#
# ## Lernziele:
#
# In diesem Versuch sollen Kenntnisse in folgenden Themen vermittelt werden:
#
# * Dokumentklassifikation: Klassifikation von Dokumenten, insbesondere Emails und RSS Feed
# * Naive Bayes Classifier: Weit verbreitete Klassifikationsmethode, welche unter bestimmten Randbedingungen sehr gut skaliert.
#
#
# ## Theorie zur Vorbereitung
#
# ### Parametrische Klassifikation und Naive Bayes Methode
#
# Klassifikatoren müssen zu einer gegebenen Eingabe $\underline{x}$ die zugehörige Klasse $C_i$ bestimmen. Mithilfe der Wahrscheinlichkeitstheorie kann diese Aufgabe wie folgt beschrieben werden: Bestimme für alle möglichen Klassen $C_i$ die bedingte Wahrscheinlichkeit $P(C_i | \underline{x})$, also die Wahrscheinlichkeit, dass die gegebene Eingabe $\underline{x}$ in Klasse $C_i$ fällt. Wähle dann die Klasse aus, für welche diese Wahrscheinlichkeit maximal ist.
#
# Die Entscheidungsregeln von Klassifikatoren können mit Methoden des "überwachten Lernens" aus Trainingsdaten ermittelt werden. Im Fall des **parametrischen Lernens** kann aus den Trainingsdaten die sogenannte **Likelihood-Funktion** $p(\underline{x} \mid C_i)$ bestimmt werden. _Anmerkung:_ Allgemein werden mit $p(...)$ kontinuierliche Wahrscheinlichkeitsfunktionen und mit $P(...)$ diskrete Wahrscheinlichkeitswerte bezeichnet.
#
# Mithilfe der **Bayes-Formel**
# $$
# P(C_i \mid \underline{x}) = \frac{p(\underline{x} \mid C_i) \cdot P(C_i)}{p(\underline{x})}
# $$
#
# kann aus der Likelihood die **a-posteriori-Wahrscheinlichkeit $P(C_i \mid \underline{x})$** berechnet werden. Darin wird $P(C_i)$ die **a-priori-Wahrscheinlichkeit** und $p(\underline{x})$ die **Evidenz** genannt. Die a-priori-Wahrscheinlichkeit kann ebenfalls aus den Trainingsdaten ermittelt werden. Die Evidenz ist für die Klassifikationsentscheidung nicht relevant, da sie für alle Klassen $C_i$ gleich groß ist.
#
# Die Berechnung der Likelihood-Funktion $p(\underline{x} \mid C_i)$ ist dann sehr aufwendig, wenn $\underline{x}=(x_1,x_2,\ldots,x_Z)$ ein Vektor von voneinander abhängigen Variablen $x_i$ ist. Bei der **Naive Bayes Classification** wird jedoch von der vereinfachenden Annahme ausgegangen, dass die Eingabevariabeln $x_i$ voneinander unabhängig sind. Dann vereinfacht sich die bedingte Verbundwahrscheinlichkeits-Funktion $p(x_1,x_2,\ldots,x_Z \mid C_i)$ zu:
#
# $$
# p(x_1,x_2,\ldots,x_Z \mid C_i)=\prod\limits_{j=1}^Z p(x_j | C_i)
# $$
#
# ### Anwendung der Naive Bayes Methode in der Dokumentklassifikation
#
# Auf der rechten Seite der vorigen Gleichung stehen nur noch von den jeweils anderen Variablen unabhängige bedingte Wahrscheinlichkeiten. Im Fall der Dokumentklassifikation sind die einzelnen Worte die Variablen, d.h. ein Ausdruck der Form $P(x_j | C_i)$ gibt an mit welcher Wahrscheinlichkeit ein Wort $x_j=w$ in einem Dokument der Klasse $C_i$ vorkommt.
# Die Menge aller Variablen $\left\{x_1,x_2,\ldots,x_Z \right\}$ ist dann die Menge aller Wörter im Dokument. Damit gibt die linke Seite in der oben gegebenen Gleichung die *Wahrscheinlichkeit, dass die Wörter $\left\{x_1,x_2,\ldots,x_Z \right\}$ in einem Dokument der Klasse $C_i$ vorkommen*, an.
#
# Für jedes Wort _w_ wird aus den Trainingsdaten die Wahrscheinlichkeit $P(w|G)$, mit der das Wort in Dokumenten der Kategorie _Good_ und die Wahrscheinlichkeit $P(w|B)$ mit der das Wort in Dokumenten der Kategorie _Bad_ auftaucht ermittelt. Trainingsdokumente werden in der Form
#
# $$
# tD=(String,Category)
# $$
# eingegeben.
#
# Wenn
#
# * mit der Variable $fc(w,cat)$ die Anzahl der Trainingsdokumente in Kategorie $cat$ in denen das Wort $w$ enthalten ist
# * mit der Variable $cc(cat)$ die Anzahl der Trainingsdokumente in Kategorie $cat$
#
# gezählt wird, dann ist
#
# $$
# P(w|G)=\frac{fc(w,G)}{cc(G)} \quad \quad P(w|B)=\frac{fc(w,B)}{cc(B)}
# $$
#
# Wird nun nach der Eingabe von $L$ Trainingsdokumenten ein neu zu klassifizierendes Dokument $D$ eingegeben und sei $W(D)$ die Menge aller Wörter in $D$, dann berechnen sich unter der Annahme, dass die Worte in $W(D)$ voneinander unabhängig sind (naive Bayes Annahme) die a-posteriori Wahrscheinlichkeiten zu:
#
# $$
# P(G|D)=\frac{\left( \prod\limits_{w \in W(D)} P(w | G) \right) \cdot P(G)}{p(D)}
# $$
# und
# $$
# P(B|D)=\frac{\left( \prod\limits_{w \in W(D)} P(w | B) \right) \cdot P(B)}{p(D)}
# $$
#
# Die hierfür notwendigen a-priori-Wahrscheinlichkeiten berechnen sich zu
#
# $$
# P(G)=\frac{cc(G)}{L}
# $$
# und
# $$
# P(B)=\frac{cc(B)}{L}
# $$
#
# Die Evidenz $p(D)$ beeinflusst die Entscheidung nicht und kann deshalb ignoriert werden.
#
#
# ## Vor dem Versuch zu klärende Fragen
#
#
# 1. Wie wird ein Naive Bayes Classifier trainiert? Was muss beim Training für die spätere Klassifikation abgespeichert werden?

# %% [markdown]
# Der Naive-Bayes Classifier wird überwacht trainiert. Dabei wird ein Classifier mit den Wahrscheinlichkeiten trainiert das ein Wort w in einem Dokument der Klasse C_i vorkommt.
#
# Die Variablen cc und fc müssen abgespeichert werden:
# * cc(cat): Anzahl der Trainingsdokumente der Kategorie cat
# * fc(w,cat): Anzahl der Trainingsdokumente der Kategorie cat in denen das Wort w vorkommt

# %% [markdown]
# 2. Wie teilt ein Naiver Bayes Classifier ein neues Dokument ein?

# %% [markdown]
# Mit Hilfe der posteriori Wahrscheinlichkeit.
#
# Diese wird mit der Likelihood-Funktion, Evidenz und der a-priori Wahrscheinlichkeiten berechnet.
# * Likelihood-Funktion: Produkt der Wahrscheinlichkeiten dass die einzelnen Wörter aus dem Dokument in der Kategorie C_i sind.
# * a-priori Wahrscheinlichkeiten: Wahrscheinlichkeit der Kategorie C_i.

# %% [markdown]
# 3. Welche naive Annahme liegt dem Bayes Classifier zugrunde? Ist diese Annahme im Fall der Dokumentklassifikation tatsächlich gegeben?

# %% [markdown]
# Annahme: Alle Eingabevektoren sind unabhängig voneinander.
#
# Nein, da Wörter in Dokumenten voneinander abhängig sind (Semantik).

# %% [markdown]
# 4. Betrachten Sie die Formeln für die Berechnung von $P(G|D)$ und $P(B|D)$. Welches Problem stellt sich ein, wenn in der Menge $W(D)$ ein Wort vorkommt, das nicht in den Trainingsdaten der Kategorie $G$ vorkommt und ein anderes Wort aus $W(D)$ nicht in den Trainingsdaten der Kategorie $B$ enthalten ist? Wie könnte dieses Problem gelöst werden?

# %% [markdown]
# P(w|G) bzw. P(w|B) sind 0 wenn w nich in G oder B ist, somit würde auch das Produkt in P(G|D) bzw. P(B|D) gleich 0 sein. Dadurch sind dann auch P(G|D) bzw. P(B|D) gleich 0 wodurch D mit einer Wahrscheinlichkeit von 0 in B bzw. G ist. Das Problem könnte gelöst werden wenn man eine Standard wert einführt (zb. 0.1), damit nicht durch ein einzelens Wort in einem Dokument D, das nicht in den Trainingsdaten ist, ein Dokument nicht zugewiesen werden kann.

# %% [markdown]
# # Durchführung
# ## Feature Extraction/ -Selection
#
# **Aufgabe:**
# Implementieren Sie eine Funktion *getwords(doc)*, der ein beliebiges Dokument in Form einer String-Variablen übergeben wird. In der Funktion soll der String in seine Wörter zerlegt und jedes Wort in _lowercase_ transformiert werden. Wörter, die weniger als eine untere Grenze von Zeichen (z.B. 3) oder mehr als eine obere Grenze von Zeichen (z.B. 20) enthalten, sollen ignoriert werden. Die Funktion soll ein dictionary zurückgeben, dessen _Keys_ die Wörter sind. Die _Values_ sollen für jedes Wort zunächst auf $1$ gesetzt werden.
#
# **Tipp:** Benutzen Sie für die Zerlegung des Strings und für die Darstellung aller Wörter mit ausschließlich kleinen Buchstaben die Funktionen *split(), strip('sep')* und *lower()* der Klasse *String*.

# %%
import pandas as pd
import feedparser
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
def getwords(doc):
    word_list = doc.split()
    word_dict = {}
    list_iligel_symbols = ["'",'!','?','.',',',';',':','-','_','*','+','~','#','=','}','[',']','{','(',')','/','$','€',"\\",'@','"','%','&','“','‘', '@','’']
    for value in word_list:
        value_str = value.lower()
        for sym in list_iligel_symbols:
            value_str = value_str.replace(sym, '')
                     
        if(len(value_str)>=3 and len(value_str)<=20):
            if(value_str in word_dict.keys()):
                word_dict[value_str] = 1
            else:
                word_dict[value_str] = 1
    return word_dict

# %%
# modifizierte Version der Methode für die Aufgabe Klassifikation von RSS-Newsfeed
def getwordsmodified(doc):
    word_list = doc.split()
    word_dict = {}
    list_iligel_symbols = ["'",'!','?','.',',',';',':','-','_','*','+','~','#','=','}','[',']','{','(',')','/','$','€',"\\",'@','"','%','&','“','‘', '@','’']
    for value in word_list:
        value_str = value.lower()
        for sym in list_iligel_symbols:
            value_str = value_str.replace(sym, '')
                     
        if(len(value_str)>=3 and len(value_str)<=20):
            if(value_str in word_dict.keys()):
                word_dict[value_str] += 1
            else:
                word_dict[value_str] = 1
    return word_dict

# %% [markdown]
# ## Classifier
#
# **Aufgabe:**
# Implementieren Sie den Naive Bayes Classifier für die Dokumentklassifikation. Es bietet sich an die Funktionalität des Klassifikators und das vom Klassifikator gelernte Wissen in einer Instanz einer Klasse _Classifier_ zu kapseln. In diesem Fall kann wie folgt vorgegangen werden:
#
# * Im Konstruktor der Klasse wird je ein Dictionary für die Instanzvariablen _fc_ und _cc_ (siehe oben) initialisiert. Dabei ist _fc_ ein verschachteltes Dictionary. Seine Keys sind die bisher gelernten Worte, die Values sind wiederum Dictionaries, deren Keys die Kategorien _Good_ und _Bad_ sind und deren Values zählen wie häufig das Wort bisher in Dokumenten der jeweiligen Kategorie auftrat. Das Dictionary _cc_ hat als Keys die Kategorien _Good_ und _Bad_. Die Values zählen wie häufig Dokumente der jeweiligen Kategorien bisher auftraten.
# * Im Konstruktor wird ferner der Instanzvariablen _getfeatures_ die Funktion *getwords()* übergeben. Die Funktion _getwords()_ wurde bereits zuvor ausserhalb der Klasse definiert. Sinn dieses Vorgehens ist, dass andere Varianten um Merkmale aus Dokumenten zu extrahieren denkbar sind. Diese Varianten könnten dann ähnlich wie die *getwords()*-Funktion ausserhalb der Klasse definiert und beim Anlegen eines *Classifier*-Objekts der Instanzvariablen _getfeatures_ übergeben werden.
# * Der Methode _incf(self,f,cat)_ wird ein Wort _f_ und die zugehörige Kategorie _cat_ des Dokuments in welchem es auftrat übergeben. In der Methode wird der *fc*-Zähler angepasst.
# * Der Methode _incc(self,cat)_ wird die Kategorie _cat_ des gerade eingelesenen Dokuments übergeben. In der Methode wird der *cc*-Zähler angepasst.
# * Die Methode _fcount(self,f,cat)_ gibt die Häufigkeit des Worts _f_ in den Dokumenten der Kategorie _cat_ zurück.
# * Die Methode _catcount(self,cat)_ gibt die Anzahl der Dokumente in der Kategorie _cat_ zurück.
# * Die Methode _totalcount(self)_ gibt die Anzahl aller Dokumente zurück.
# * Der Methode _train(self,item,cat)_ wird ein neues Trainingselement, bestehend aus der Betreffzeile (*item*) und der entsprechenden Kategorisierung (*cat*) übergeben. Der String _item_ wird mit der Instanzmethode _getfeatures_ (Diese referenziert *getwords()*) in Worte zerlegt. Für jedes einzelne Wort wird dann *incf(self,f,cat)* aufgerufen. Ausserdem wird für das neue Trainingsdokument die Methode _incc(self,cat)_ aufgerufen.
# * Die Methode _fprob(self,f,cat)_ berechnet die bedingte Wahrscheinlichkeit $P(f | cat)$ des Wortes _f_ in der Kategorie _cat_ entsprechend der oben angegebenen Formeln, indem sie den aktuellen Stand des Zählers _fc(f,cat)_ durch den aktuellen Stand des Zählers _cc(cat)_ teilt.
# * Die Methode _fprob(self,f,cat)_ liefert evtl. ungewollt extreme Ergebnisse, wenn noch wenig Wörter im Klassifizierer verbucht sind. Kommt z.B. ein Wort erst einmal in den Trainingsdaten vor, so wird seine Auftrittswahrscheinlichkeit in der Kategorie in welcher es nicht vorkommt gleich 0 sein. Um extreme Wahrscheinlichkeitswerte im Fall noch selten vorkommender Werte zu vermeiden, soll zusätzlich zur Methode _fprob(self,f,cat)_ die Methode _weightedprob(self,f,cat)_ implementiert und angewandt werden. Der von ihr zurückgegebene Wahrscheinlichkeitswert könnte z.B. wie folgt berechnet werden:$$wprob=\frac{initprob+count \cdot fprob(self,f,cat)}{1+count},$$ wobei $initprob$ ein initialer Wahrscheinlichkeitswert (z.B. 0.5) ist, welcher zurückgegeben werden soll, wenn das Wort noch nicht in den Trainingsdaten aufgetaucht ist. Die Variable $count$ zählt wie oft das Wort $f$ bisher in den Trainingsdaten auftrat. Wie zu erkennen ist, nimmt der Einfluss der initialen Wahrscheinlichkeit ab, je häufiger das Wort in den Trainingsdaten auftrat.
# * Nach dem Training soll ein beliebiges neues Dokument (Text-String) eingegeben werden können. Für dieses soll mit der Methode _prob(self,item,cat)_ die a-posteriori-Wahrscheinlichkeit $P(cat|item)$ (Aufgrund der Vernachlässigung der Evidenz handelt es sich hierbei genaugenommen um das Produkt aus a-posteriori-Wahrscheinlichkeit und Evidenz), mit der das Dokument _item_ in die Kategorie _cat_ fällt berechnet werden. Innerhalb der Methode _prob(self,item,cat)_ soll zunächst die Methode _weightedprob(self,f,cat)_ für alle Wörter $f$ im Dokument _item_ aufgerufen werden. Die jeweiligen Rückgabewerte von _weightedprob(self,f,cat)_ werden multipliziert. Das Produkt der Rückgabewerte von _weightedprob(self,f,cat)_ über alle Wörter $f$ im Dokument muss schließlich noch mit der a-priori Wahrscheinlichkeit $P(G)$ bzw. $P(B)$ entsprechend der oben aufgeführten Formeln multipliziert werden. Das Resultat des Produkts wird an das aufrufende Programm zurück gegeben, die Evidenz wird also vernachlässigt (wie oben begründet).
#
#
#
# Ein Dokument _item_ wird schließlich der Kategorie _cat_ zugeteilt, für welche die Funktion _prob(self,item,cat)_ den höheren Wert zurück gibt. Da die Rückgabewerte in der Regel sehr klein sind, werden in der Regel folgende Werte angezeigt:
# * Wenn mit $g$ der Rückgabewert von _prob(self,item,cat=G)_ und mit $b$ der Rückgabewert von _prob(self,item,cat=B)_ bezeichnet wird dann ist die Wahrscheinlichkeit, dass $item$ in die Kategorie $G$ fällt, gleich:
# $$
# \frac{g}{g+b}
# $$
# * und die Wahrscheinlichkeit, dass $item$ in die Kategorie $B$ fällt, gleich:
# $$
# \frac{b}{g+b}
# $$

# %%
class Classifier:
    categories = []
    
    def __init__(self, getfeatures, categories):
        self.categories = categories
        self.cc = {}
        for category in self.categories:
            self.cc[category] = 0
        self.fc = {}
        self.getfeatures = getfeatures

    def incf(self, f, cat, count):
        if f in self.fc.keys():
            if cat in self.fc[f].keys():
                self.fc[f][cat] += count 
            else:
                self.fc[f][cat] = count 
        elif f not in self.fc.keys():
            self.fc[f] = {}
            for category in self.categories:
                self.fc[f][category] = 0

            self.fc[f][cat] += count       

    def incc(self, cat):
        self.cc[cat] += 1

    def fcount(self, f, cat):
        if f in self.fc.keys():
            x = self.fc[f][cat]
        else:
            x = 0
        return x
          
    def catcount(self, cat):
        return self.cc[cat]

    def totalcount(self):
        return sum(self.cc.values())

    def train(self, item, cat):
        word_dict = self.getfeatures(item)
        for key in word_dict.keys():
            self.incf(key, cat, word_dict[key])
        self.incc(cat)

    def fprob(self, f, cat):
        x = self.fcount(f, cat)/self.catcount(cat)
        return x
 
    def weightedprob(self, f, cat):
        fProb = self.fprob(f, cat)
        initProb = 0.5
        count = 0
        for value in self.categories:
            count += self.fcount(f, value)
        
        x = (initProb + count*fProb)/ (1+count)
        return x

    def prob(self, item, cat):
        word_dict = self.getfeatures(item) 
        prodProb = 1
        for value in word_dict:
            prodProb *= self.weightedprob(value, cat)
        catCount = self.catcount(cat)
        totCount = self.totalcount()
        apriori = catCount/totCount
        x = prodProb*apriori
        return x

    def decision(self,item):
        g = self.prob(item, self.categories[0])
        b = self.prob(item, self.categories[1])
        if b + g == 0: # Für den Fall, dass das Dokument zu keinen der beiden Kategorien zugeordnet werden kann
            good = 0.5
            bad = 0.5
        else:
            good = g/(g+b)
            bad = b/(g+b)
        result = ''
        if b < g:
            print(f"der Text gehört mit einer Wahrscheinlichkeit von {good} zu der Kategorie '{self.categories[0]}'")
            result = self.categories[0]
        else:
            print(f"der Text gehört mit einer Wahrscheinlichkeit von {bad} zu der Kategorie '{self.categories[1]}'")
            result = self.categories[1]
        return result

# %% [markdown]
# ## Test
#
# **Aufgabe:**
# Instanzieren Sie ein Objekt der Klasse _Classifier_ und übergeben Sie der _train()_ Methode dieser Klasse mindestens 8 kategorisierte Dokumente (Betreffzeilen als Stringvariablen zusammen mit der Kategorie Good oder Bad). Definieren Sie dann ein beliebig neues Dokument und berechnen Sie für dieses die Kategorie, in welches es mit größter Wahrscheinlichkeit fällt. Benutzen Sie für den Test das in der
# [NLP Vorlesung Document Classification](https://griesshaber.pages.mi.hdm-stuttgart.de/nlp/06classification/07classificationNaiveBayes.html)
# ausführlich beschriebene Beispiel zu implementieren. Berechnen Sie die Klassifikatorausgabe des Satzes _the money jumps_.

# %%
data = pd.read_csv('./Data/train.csv',index_col=0)

data = data[data['text'].notna()]

cats = []
for value in data["label"]:
    if(value == 0):
        cats.append("Good")
    else:
        cats.append("Bad")

data["category"] = cats

# %%
test_data = data.head(10000)
category = ["Good", "Bad"]
classifier = Classifier(getwords, category)
classifier_mod = Classifier(getwordsmodified, category)

texts = []
cats = []
for value in test_data["text"]:
    texts.append(value)

for value in test_data["category"]:
    cats.append(value)

for i in range(0,50):
    classifier.train(texts[i], cats[i])

for i in range(0,50):
    classifier_mod.train(texts[i], cats[i])

# %%
test_string = "The money jumps."

classifier.decision(test_string)
classifier_mod.decision(test_string)
# Out:
# der Text gehört mit einer Wahrscheinlichkeit von 0.7091537106296171 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6736648675294423 zu der Kategorie 'Good'
# 'Good'

# %% [markdown]
# ## Klassifikation von RSS Newsfeeds
# Mit dem unten gegebenen Skript werden Nachrichten verschiedener Newsserver geladen und ausgegeben. Ändern Sie diese Methode ab, damit diese Strings gespeichert werden und für ein Training benutzt werden können.

# %%
def countFeed(feedList, title, should_print=False):
    if should_print:
        print(f"--------------------News from {title}------------------------")
    count = 0
    for feed in feedList:
        if should_print:
            print()
            print("*"*30)
            print(feed)
        f=feedparser.parse(feed)
        for e in f.entries:
            if hasattr(e, 'title') and hasattr(e, 'description'):
                if should_print:
                    print('\n---------------------------')
                fulltext=stripHTML(e.title+' '+e.description)
                if should_print:
                    print(fulltext)
                count += 1
    if should_print:
        print("----------------------------------------------------------------")
        print("----------------------------------------------------------------")
        print("----------------------------------------------------------------")
    return count

# Unsere Funktion zum Abspeichern der Strings
def getTextFeed(feedList, title, cat):
    text = {}
    for feed in feedList:
        if(feed == 'http://rss.golem.de/rss.php?r=sw&feed=RSS0.91'):
            cat = 'Tech'
        elif(feed == 'http://www.welt.de/?service=Rss' or feed == 'http://newsfeed.zeit.de/politik/index'):
            cat = 'NonTech'
        f=feedparser.parse(feed)
        for e in f.entries:
            if hasattr(e, 'title') and hasattr(e, 'description'):
                fulltext=stripHTML(e.title+' '+e.description)
                text[fulltext] = cat
    return text
                
def stripHTML(h):
    p=''
    s=0
    for c in h:
        if c=='<': 
            s=1
        elif c=='>':
            s=0
            p+=' '
        elif s==0:
            p+=c
    return p

trainTech=['http://rss.chip.de/c/573/f/7439/index.rss',
           #'http://feeds.feedburner.com/netzwelt',
           'http://rss1.t-online.de/c/11/53/06/84/11530684.xml',
           'http://www.computerbild.de/rssfeed_2261.xml?node=13',
           'http://www.heise.de/newsticker/heise-top-atom.xml']

trainNonTech=['http://newsfeed.zeit.de/index',
              'http://newsfeed.zeit.de/wirtschaft/index',
              'http://www.welt.de/politik/?service=Rss',
              'http://www.spiegel.de/schlagzeilen/tops/index.rss',
              'https://rss.sueddeutsche.de/alles',
              'http://www.faz.net/rss/aktuell/']

test=['http://rss.golem.de/rss.php?r=sw&feed=RSS0.91',
      'http://newsfeed.zeit.de/politik/index',  
      'http://www.welt.de/?service=Rss']

countnews={}
countnews['tech']=countFeed(trainTech, 'trainTech')
countnews['nontech']=countFeed(trainNonTech, 'trainNonTech')
countnews['test']=countFeed(test, 'test')

print('Number of used trainings samples in categorie tech',countnews['tech'])
print('Number of used trainings samples in categorie notech',countnews['nontech'])
print('Number of used test samples',countnews['test'])
print('--'*30)

news_text={}
news_text['tech'] = {}
news_text['nontech'] = {}
news_text['test'] = {}
news_text['tech'] = getTextFeed(trainTech, 'trainTech', 'Tech')
news_text['nontech'] = getTextFeed(trainNonTech, 'trainNonTech', 'NonTech')
news_text['test'] = getTextFeed(test, 'test','')
# Out:
# Number of used trainings samples in categorie tech 160
# Number of used trainings samples in categorie notech 114
# Number of used test samples 85
# ------------------------------------------------------------

# %% [markdown]
# **Aufgaben:**
# 1. Trainieren Sie Ihren Naive Bayes Classifier mit allen Nachrichten der in den Listen _trainTech_ und _trainNonTech_ definierten Servern. Weisen Sie für das Training allen Nachrichten aus _trainTech_ die Kategorie _Tech_ und allen Nachrichten aus _trainNonTech_ die Kategorie _NonTech_ zu.

# %%
categories = ["Tech", "NonTech"]

classifier_rss = Classifier(getwords, categories)
classifier_rss_mod = Classifier(getwordsmodified, categories)

tech_texts = []

tech_texts = news_text['tech'].keys()
nontech_texts = news_text['nontech'].keys()
test_texts = news_text['test'].keys()

for text in tech_texts:
    classifier_rss.train(text, "Tech")
for text in nontech_texts:
    classifier_rss.train(text, "NonTech")

for text in tech_texts:
    classifier_rss_mod.train(text, "Tech")
for text in nontech_texts:
    classifier_rss_mod.train(text, "NonTech")

# %% [markdown]
# 2. Nach dem Training sollen alle Nachrichten aus der Liste _test_ vom Naive Bayes Classifier automatisch klassifiziert werden. Gehen Sie davon aus, dass alle Nachrichten von [http://rss.golem.de/rss.php?r=sw&feed=RSS0.91](http://rss.golem.de/rss.php?r=sw&feed=RSS0.91) tatsächlich von der Kategorie _Tech_ sind und alle Nachrichten von den beiden anderen Servern in der Liste _test_ von der Kategorie _NonTech_ sind. Bestimmen Sie die _Konfusionsmatrix_ und die _Accuracy_ sowie für beide Klassen _Precision, Recall_ und _F1-Score_. Diese Qualitätsmetriken sind z.B. in [NLP Vorlesung Document Classification](https://griesshaber.pages.mi.hdm-stuttgart.de/nlp/06classification/06classificationMetrics.html) definiert.

# %%
pred_cat = []
test_true = []
pred_cat_mod = []
test_true_mod = []

for text in test_texts:
    test_true.append(news_text['test'][text])
    pred_cat.append(classifier_rss.decision(text))
    
for text in test_texts:
    test_true_mod.append(news_text['test'][text])
    pred_cat_mod.append(classifier_rss_mod.decision(text))
# Out:
# der Text gehört mit einer Wahrscheinlichkeit von 0.593347366925435 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8221022270280774 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.65498495391506 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5479330562801629 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6460027184283291 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7906398762827542 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9315472759773411 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5201745464785129 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6095586168020596 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8697858943186932 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9721595920744235 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7592886602011651 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6875055254233744 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8136503471767943 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.803103138037457 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7120413521372463 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.820930311031262 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8417448720662687 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6737657354689129 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.835255032497172 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7327632201991255 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7043274035357318 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8957163383565764 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6153862006782145 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5972810611052219 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7159413133069508 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.556244212429309 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8011252341106643 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5038388012338695 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8643998359418075 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5320985475204626 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6330792247525873 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5048869430287793 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8402358082136577 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7936258559722691 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.594026541736883 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9274014377205227 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8543242123126823 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5232302386212507 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7002519267565581 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.992195385024779 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8631719859771606 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9352928782775478 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6154678744157884 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6463703978164514 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7288291056538787 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9488303686242561 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6493820144608088 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9570493730838932 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7702667756744173 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8378442941929392 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7180599082252572 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7086971167481062 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7083151275820038 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6761991124816943 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6027753846866173 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8062109841544035 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8726685830024794 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.531290744206548 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7414131520145795 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7462145957682809 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.500044916744096 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9102831829055992 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9330386624402557 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9200521075426672 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8796143511034392 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9488355369450914 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8949497077827218 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9112666480612271 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7804738319863348 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7473929879822411 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7847002595144245 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9189729244612291 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9350934488101443 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9256040875784202 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6791902476992477 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7089055415945348 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.726071963633074 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.780958829168389 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6540147299465581 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5843473050622073 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9869328822218458 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8661978342786701 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9926066221645953 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5399482423954557 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8783311431010676 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8022713806699961 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5174114569988342 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5746028071062569 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8859047118061216 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9655430248561812 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5898160273650593 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5514988562351958 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9382666490054974 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9913022894565238 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7479434120635783 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8040472124930289 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8868953886258343 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8843429080194142 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6766690360550832 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8925165150689637 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9246316348370762 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7967926626190989 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8121126222447148 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8203608836793863 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6049882670565933 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9149139459662532 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5685619544895786 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7021905451867471 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6694955559433691 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6176173513494152 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7672297585461207 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5901534579503775 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8494186714145948 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5167032912544433 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7698473791942347 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5460741994608046 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.935823676512304 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8654005703719115 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6770887094550977 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9543662834045934 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7610789973998511 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5425368277414455 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8033664869525933 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.997163238082346 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9445075909230103 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9574560737233866 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5511293597176777 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.820883562382504 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6749355168893488 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9719566558657219 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6923708847287793 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9688055357988665 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7845507955661658 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9023925109896721 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8974175698458164 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6798894494654291 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7998290407739954 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7437193933497612 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5812673314571093 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8559409525674848 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8961108930394108 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5578114198562559 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7717142861908146 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8040223332596848 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5392175518450768 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9682365923423502 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9797903313935185 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9367197124324392 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9468114881585699 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9686839544581699 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9130701170925748 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9384621062581282 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8561261180810594 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8361480821386219 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8469548404102398 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9553006942748037 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9219024140266291 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9467022912389293 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7082902725829094 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7123613506583779 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7725112634691556 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8380470378460225 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6524994175592462 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6374366147327314 zu der Kategorie 'Tech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9957535736125435 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9286634138069066 zu der Kategorie 'NonTech'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9988542499036643 zu der Kategorie 'NonTech'

# %%
cm = confusion_matrix(test_true, pred_cat)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)

disp.plot()

plt.show()
# TP | FN
#--------
# FP | TN

# %%
cm_mod = confusion_matrix(test_true_mod, pred_cat_mod)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_mod)

disp.plot()

plt.show()

# %%
# Bestimmen Sie die Konfusionsmatrix und die Accuracy sowie für beide Klassen Precision, Recall und F1-Score. 
# Accuracy
# True Tech + True NonTech / alles
acc = (cm[0][0] + cm[1][1])/sum(sum(cm))

# Tech
    # Precision: True Tech / (True Tech + False Tech)
prec_tech = cm[0][0] / (cm[0][0] + cm[1][0])
    # Recall: True Tech / (True Tech + Flase NonTech)
recall_tech = cm[0][0] / (cm[0][0] + cm[0][1])
    # F1-Score: 2* Precision * Recall / (Precision + Recall)
f1_tech = 2*((prec_tech*recall_tech)/(prec_tech + recall_tech))

# NonTech
    # Precision: True NonTech / (True NonTech + False NonTech)
prec_nonTech = cm[1][1] / (cm[1][1] + cm[0][1])
    # Recall: True NonTech / (True NonTech + False Tech)
recall_nonTech = cm[1][1] / (cm[1][1] + cm[1][0])
    # F1-Score: 2* Precision * Recall / (Precision + Recall)
f1_nonTech = 2*((prec_nonTech*recall_nonTech)/(prec_nonTech + recall_nonTech))

# %%
print(f"Accuracy: {acc}")
print("--------Tech---------")
print(f"Precision: {prec_tech}")
print(f"Recall: {recall_tech}")
print(f"F1-Score: {f1_tech}")
print("-------NonTech-------")
print(f"Precision: {prec_nonTech}")
print(f"Recall: {recall_nonTech}")
print(f"F1-Score: {f1_nonTech}")
# Out:
# Accuracy: 0.8452380952380952
# --------Tech---------
# Precision: 0.8444444444444444
# Recall: 0.8636363636363636
# F1-Score: 0.853932584269663
# -------NonTech-------
# Precision: 0.8461538461538461
# Recall: 0.825
# F1-Score: 0.8354430379746836

# %% [markdown]
# 3. Diskutieren Sie das Ergebnis.

# %% [markdown]
# * Trotz der Vernachlässigung der Semantik im Dokument ergibt sich eine Accuracy von 71,76%
# * Die Precision ist für nonTech Artikel besser als für Tech, der Classifier ist bei non Tech Artikel zuverlässiger
# * Der Recall für Tech ist besser als für nonTech, Tech Artikel werden öfter erkannt als nonTech Artikel
# * Der F1-Score ist bei Kategorie Tech höher als bei nonTech. Der Classifier ist besser angepasst auf Tech Artikel
# * Die Trainings Daten habe 160 Tech Dokumente und 105 nonTech Dokumente, somit ist der Classifier besser auf Tech Dokumente trainiert

# %% [markdown]
# 4. Wie könnte die Klassifikationsgüte durch Modifikation der *getwords()*-Methode verbessert werden? Implementieren Sie diesen Ansatz und vergleichen Sie das Ergebnis mit dem des ersten Ansatzes.

# %%
# Accuracy
# True Tech + True NonTech / alles
acc_mod = (cm_mod[0][0] + cm_mod[1][1])/sum(sum(cm_mod))

# Tech
    # Precision: True Tech / (True Tech + False Tech)
prec_tech_mod = cm_mod[0][0] / (cm_mod[0][0] + cm_mod[1][0])
    # Recall: True Tech / (True Tech + Flase NonTech)
recall_tech_mod = cm_mod[0][0] / (cm_mod[0][0] + cm_mod[0][1])
    # F1-Score: 2* Precision * Recall / (Precision + Recall)
f1_tech_mod = 2*((prec_tech_mod*recall_tech_mod)/(prec_tech_mod + recall_tech_mod))

# NonTech
    # Precision: True NonTech / (True NonTech + False NonTech)
prec_nonTech_mod = cm_mod[1][1] / (cm_mod[1][1] + cm_mod[0][1])
    # Recall: True NonTech / (True NonTech + False Tech)
recall_nonTech_mod = cm_mod[1][1] / (cm_mod[1][1] + cm_mod[1][0])
    # F1-Score: 2* Precision * Recall / (Precision + Recall)
f1_nonTech_mod = 2*((prec_nonTech_mod*recall_nonTech_mod)/(prec_nonTech_mod + recall_nonTech_mod))

# %%
print(f"Accuracy: {acc_mod}")
print("--------Tech---------")
print(f"Precision: {prec_tech_mod}")
print(f"Recall: {recall_tech_mod}")
print(f"F1-Score: {f1_tech_mod}")
print("-------NonTech-------")
print(f"Precision: {prec_nonTech_mod}")
print(f"Recall: {recall_nonTech_mod}")
print(f"F1-Score: {f1_nonTech_mod}")
# Out:
# Accuracy: 0.8095238095238095
# --------Tech---------
# Precision: 0.78
# Recall: 0.8863636363636364
# F1-Score: 0.8297872340425532
# -------NonTech-------
# Precision: 0.8529411764705882
# Recall: 0.725
# F1-Score: 0.7837837837837837

# %% [markdown]
# ### Unsere Modefikation:
# getwordsmodified() zählt wie oft ein Wort in eine Artikel vorkommt und diese Zusatzinformation wird auch beim trainieren verwendet.
# Somit werden die Wörte nach Häufigkeit gewichtet.
#
# Durch unsere Modifikationen hat sich die Accuracy von 71% auf 75% verbessert (schwankt je nach Testdaten).
# Die Precision Werte sind bei beiden Kategorien gestiegen, der Wert bleibt jedoch höher bei der Kategorie nonTech.
# Die Recall Werte sind auch gestiegen, und auch hier bleibt der Wert für die Kategorie Tech höher (ähnlich wie bei nicht modifizierten).
# Der F1-Score erhöht sich auch bei beiden Kategorien, ist bei Tech aber höher als bei nonTech.

# %% [markdown]
# # Hypothese
# ### Durch das Entfernen der Stoppwörter ergibt sich eine höhere Accuracy des Naive Bayes Classifiers, da die Klassifikation nicht mehr von durch die Stoppwörter verzerrt wird.

# %% [markdown]
# Bei Stoppwörtern handelt es sich um Wörter (``[i, am, the, and, ...]``), welche einen niedrigen Grad an Informationen darbieten und somit wenig Relevanz für die Klassifikation von Dokumenten aufweisen.
#
# Durch die Entfernung dieser Wörter erhoffen wir uns eine bessere Klassifizierung der Dokumente, da diese nicht mehr duch die Häufigkeit der Stoppwörter beeinflusst werden.
#
# Da die Character-Grenze von ``3 <= string >= 20`` nach unserer Vermutung als eine provisorische Stoppwörter-Entfernung dienen soll, wurde diese entfernt und durch unsere Modifikation ersetzt.

# %%
stopwords_list = stopwords.words('english')
# stopwords_list

# %%
# modifizierte Version der Methode für die Hypothese
def getwordsmodified_stop(doc, stopwords_list=stopwords_list):
    word_list = doc.split()
    word_dict = {}
    list_iligel_symbols = ["'",'!','?','.',',',';',':','-','_','*','+','~','#','=','}','[',']','{','(',')','/','$','€',"\\",'@','"','%','&','“','‘', '@','’']
    for value in word_list:
        value_str = value.lower()
        for sym in list_iligel_symbols:
            value_str = value_str.replace(sym, '')
        
        if value_str not in stopwords_list: # Modification
 
            # if(len(value_str)>=3 and len(value_str)<=20):
            if(value_str in word_dict.keys()):
                word_dict[value_str] += 1
            else:
                word_dict[value_str] = 1
    return word_dict

# %%
# Test block
a = "I am Ben and I love my life since I started my job at the university as a Researcher."
getwordsmodified_stop(doc=a)
# Out:
# {'ben': 1,
#  'love': 1,
#  'life': 1,
#  'since': 1,
#  'started': 1,
#  'job': 1,
#  'university': 1,
#  'researcher': 1}

# %%
data = pd.read_csv('./Data/train.csv',index_col=0)

data = data[data['text'].notna()]

cats = []
for value in data["label"]:
    if(value == 0):
        cats.append("Good")
    else:
        cats.append("Bad")

data["category"] = cats

# %%
data.head()
# Out:
#                                                 title              author  \
# id
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2                   Why the Truth Might Get You Fired  Consortiumnews.com
# 3   15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                  text  label category
# id
# 0   House Dem Aide: We Didn’t Even See Comey’s Let...      1      Bad
# 1   Ever get the feeling your life circles the rou...      0     Good
# 2   Why the Truth Might Get You Fired October 29, ...      1      Bad
# 3   Videos 15 Civilians Killed In Single US Airstr...      1      Bad
# 4   Print \r\nAn Iranian woman has been sentenced ...      1      Bad

# %%
test_data = data.head(10000)
real_test_data = data.iloc[1000:1500, :] # For later

category = ["Good", "Bad"]

classifier = Classifier(getwords, category)
classifier_mod = Classifier(getwordsmodified, category)
classifier_mod_stop = Classifier(getwordsmodified_stop, category)

texts = []
cats = []

for value in test_data["text"]:
    texts.append(value)

for value in test_data["category"]:
    cats.append(value)

# Her wurden, im Gegensatz zur Aufgabe davor, mehr Trainigsdaten verwendet für einen besseren Vergleich
for i in range(0, 1000):
    classifier.train(texts[i], cats[i])
    classifier_mod.train(texts[i], cats[i])
    classifier_mod_stop.train(texts[i], cats[i])

# %%
test_string = "The money jumps."

classifier.decision(test_string)
classifier_mod.decision(test_string)
classifier_mod_stop.decision(test_string)
# Out:
# der Text gehört mit einer Wahrscheinlichkeit von 0.5555046603421558 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5495354730080049 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5210285581408601 zu der Kategorie 'Bad'
# 'Bad'

# %%
pred_cat = []
test_true = []

pred_cat_mod = []
test_true_mod = []

pred_cat_mod_stop = []
test_true_mod_stop = []

for index, row in real_test_data.iterrows():
    test_true.append(row['category'])
    pred_cat.append(classifier.decision(row['text']))
    
    test_true_mod.append(row['category'])
    pred_cat_mod.append(classifier_mod.decision(row['text']))

    test_true_mod_stop.append(row['category'])
    pred_cat_mod_stop.append(classifier_mod_stop.decision(row['text']))
# Out:
# der Text gehört mit einer Wahrscheinlichkeit von 0.878803464404337 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9710738316161185 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9710738316161185 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999979138 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999993351 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999550696 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999921205734 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999993 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999974 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998976 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999996719953 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999979144946 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.985522633455657 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999958227 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997985667 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999973579477178 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999993 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999087 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999983078711022 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6125005263792405 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7469991850081833 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7469991850081833 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998970969 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999948133815 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9937241000844206 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9946464946149914 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9752875477524551 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999993698 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998376 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999995246030589 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9505758515770684 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999992601684895 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.99999999994368 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999556278371126 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7601795396615054 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5743562115675851 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5113482678037655 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.549519338187173 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999981369 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999966626653393 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997391665 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999978577744547 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9997347232781788 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999065733193475 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9977843943707717 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8229613826726091 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8731336256750348 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8448449557128724 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8170699501540263 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999876 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999988167 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999997390526386 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9998607268150658 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.99724074242717 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999942 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999928955342318 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9997432452397915 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9780890768885033 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7278269495107682 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999977 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999985 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999875 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999972105 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7304488611427339 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6146812395235492 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9998091151051098 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999370214 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999694096 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999986418612 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999997875 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999996377 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999995854830636 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.790064677231007 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6908340005380672 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6383858471487927 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999980334434 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999339047044 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999592234829184 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9976016974579179 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.69593503790019 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9996382435523697 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999299266061 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9996786749182683 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9943175977169149 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999966860085 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999670895992 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999993696103896 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999991 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999768 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998329332 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999974756328115 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9998529444147012 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9753164899225294 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8157541242974838 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999960627021901 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999964255 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999986951386 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999962588 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999985864468 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999933875190304 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999897142 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999956248 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999987438 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999996536 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999957222672 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999816534235566 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999998679803068 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999888642046972 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8449260742448286 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999992 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999992117705 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9183441984999794 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999844259785614 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999982 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999997888 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999989 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999983 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999989 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999986162724 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.99999999993525 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999995515845 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999990994 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999978751 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999996905 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998855 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999060785 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999255 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999853182 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999807700364 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999991944959 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997841662 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9998874608617516 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999994491 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999575595 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999996 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999987498055474 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999995372221232 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999940835986946 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8503871641984554 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8233852308236972 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7351032622660748 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999979 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999949 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999962657 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7895990775577005 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5258628993351682 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5750892930969784 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999979 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9998992123512456 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9936119701144045 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5943738364720055 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999837103551 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999988454803 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999797444562 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998536 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999993287 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999931121 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998376209 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998631586 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999943791965 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7446786968013067 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8380195798829915 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8034094773639443 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999984 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999985422765 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999994627421621 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999786483407 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999913 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999991156 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999732227599 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999253084340304 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999987495 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999990761 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999997812872094 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8313465222455728 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999889794136803 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999997 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999989 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999967 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999580129522 zu der Kategorie 'Good'
# ...
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999997754 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999986 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999330544 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999937370895 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7726491291977833 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999997 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999175 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999991891 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999886925 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999938 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5061224489795919 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5088786583360737 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5088786583360737 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5858398578518265 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8949380702047925 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9586715942196594 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999994 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999998954 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999474983384945 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999989 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997851509 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9994121170314041 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998611 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997504445 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999995829074361 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999707109 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999969397 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999979962 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999975 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999998951 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998244069 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999993917544 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999990415205 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999998752112673 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999793 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999975268 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999998670652 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999661105692477 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999992091852128 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999999941643645 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999997676053521 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999988727 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999891 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999233 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999956345529 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999952554 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999998676515623 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.999983323757797 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7044081449988812 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7406976744186047 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.7406976744186047 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8298933004208415 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.6801940501761818 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.601598076825075 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999997592 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999997438461 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999996415853 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999997 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999998 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999975094552246 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9993486627572702 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8151964552835692 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999047912 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9935974544351353 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999714 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999999 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999999956 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999999999994537 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9925762759615004 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9858812372544782 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.8316746010245152 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 1.0 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999850011538409 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9999531013881703 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.9993806444492295 zu der Kategorie 'Good'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'
# der Text gehört mit einer Wahrscheinlichkeit von 0.5 zu der Kategorie 'Bad'

# %%
cm = confusion_matrix(test_true, pred_cat)
cm_mod = confusion_matrix(test_true_mod, pred_cat_mod)
cm_mod_stop = confusion_matrix(test_true_mod_stop, pred_cat_mod_stop)

# %%
acc = (cm[0][0] + cm[1][1])/sum(sum(cm))
acc_mod = (cm_mod[0][0] + cm_mod[1][1])/sum(sum(cm_mod))
acc_mod_stop = (cm_mod_stop[0][0] + cm_mod_stop[1][1])/sum(sum(cm_mod_stop))

# %%
print("Normal Classifier: ", acc)
print("Word Count Classifier: ", acc_mod)
print("Word Count without Stopwords Classifier: ", acc_mod_stop)
# Out:
# Normal Classifier:  0.424
# Word Count Classifier:  0.472
# Word Count without Stopwords Classifier:  0.478

# %% [markdown]
# ## Results:

# %% [markdown]
# Bei der Klassifierung für den Satz ``The money jumps`` wird bei der Classifier Variante ohne Stoppwörter, im Gegensatz zu den anderen Classifier, die richtige Klasse erkannt == `bad`.
#
# Unsere Hypothese hat sich insofern bestätigt, dass wir im Vergleich zu dem **Normal Classifier** einen besseren Accuracy-Wert bekommen. Das zeigt, dass die Entfernung der Stoppwörter aus den Dokumenten einen positiven Einfluss auf die Klassifizierung aufweist.
#
# Bei dem Vergleich zu dem **Word Count Classifier** hat sich die Accuracy lediglich nur minimal erhöht. Das zeigt, dass die meisten Stoppwörter in die Character-Grenze fallen und somit die Stopwörter größtenteils bereits entfernt werden.
#
# Es zeigt sich, dass Preprocessing einen großes Einfluss auf die Klassifizierung von Dokumenten hat.
#
# Da das Training der Classifier stark von der Menge der Daten abhängig ist - auch beim Testen - ergibt sich meistens unsere minimale Abweichung zwischen **Word Count Classifier** und **Word Count without Stopwords Classifier**, aber in selteten Fällen auch der umgekehrte Fall, da beiden Classifier einen sehr ähnlichen Ablauf haben.
#
#
# <br>
# <br>
# Einige Dokumente sind so lang, dass die Wahrscheinlichkeiten die sie als `good` oder `bad` klassifizieren so nah an `0` geratten dass sie als `0` betrachtet werden und somit nicht gut von dem Classifier erkannt werden.
